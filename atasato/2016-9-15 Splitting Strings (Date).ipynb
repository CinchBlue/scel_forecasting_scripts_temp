# %%
# Splitting Strings

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from ipywidgets import interact, fixed
# %matplotlib inline

print("Packages imported successfully.")
# Out:
# Packages imported successfully.

# %%
# Data from: Southern Great Plains, Central Facility, Oklahoma
# Dates: 2013-6-25 to 2014-6-25
input_data = pd.read_csv("20030625.csv")

print(type(input_data))
print(input_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        DATE (MM/DD/YYYY)    CST  Global PSP-A [W/m^2]  Global PSP-B [W/m^2]  \
# 0              6/25/2003  05:15              -2.52450              -2.00050
# 1              6/25/2003  05:16              -2.08760              -1.47810
# 2              6/25/2003  05:17              -1.48420              -0.99684
# 3              6/25/2003  05:18              -1.00560              -0.37811
# 4              6/25/2003  05:19              -0.51322               0.10312
# 5              6/25/2003  05:20               0.02774               0.63935
# 6              6/25/2003  05:21               0.76983               1.33370
# 7              6/25/2003  05:22               1.58130               2.09680
# 8              6/25/2003  05:23               2.33720               2.80490
# 9              6/25/2003  05:24               3.16950               3.63670
# 10             6/25/2003  05:25               3.85610               4.35170
# ...

# %%
dates = input_data["DATE (MM/DD/YYYY)"]
print(dates)
# Out:
# 0         6/25/2003
# 1         6/25/2003
# 2         6/25/2003
# 3         6/25/2003
# 4         6/25/2003
# 5         6/25/2003
# 6         6/25/2003
# 7         6/25/2003
# 8         6/25/2003
# 9         6/25/2003
# 10        6/25/2003
# 11        6/25/2003
# 12        6/25/2003
# 13        6/25/2003
# 14        6/25/2003
# 15        6/25/2003
# 16        6/25/2003
# 17        6/25/2003
# 18        6/25/2003
# 19        6/25/2003
# 20        6/25/2003
# 21        6/25/2003
# 22        6/25/2003
# 23        6/25/2003
# 24        6/25/2003
# 25        6/25/2003
# 26        6/25/2003
# 27        6/25/2003
# 28        6/25/2003
# 29        6/25/2003
#             ...
# 266757    6/25/2004
# 266758    6/25/2004
# 266759    6/25/2004
# 266760    6/25/2004
# 266761    6/25/2004
# 266762    6/25/2004
# 266763    6/25/2004
# 266764    6/25/2004
# 266765    6/25/2004
# 266766    6/25/2004
# 266767    6/25/2004
# 266768    6/25/2004
# 266769    6/25/2004
# 266770    6/25/2004
# ...

# %%
dates_str = dates.astype(str)
print(type(dates_str[0]))
# Out:
# <class 'str'>

# %%
dates_mdy = dates.str.split('/', expand=True)
print(type(dates_mdy))
dates_mdy
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         0   1     2
# 0       6  25  2003
# 1       6  25  2003
# 2       6  25  2003
# 3       6  25  2003
# 4       6  25  2003
# 5       6  25  2003
# 6       6  25  2003
# 7       6  25  2003
# 8       6  25  2003
# 9       6  25  2003
# 10      6  25  2003
# 11      6  25  2003
# 12      6  25  2003
# 13      6  25  2003
# 14      6  25  2003
# 15      6  25  2003
# 16      6  25  2003
# 17      6  25  2003
# 18      6  25  2003
# 19      6  25  2003
# 20      6  25  2003
# 21      6  25  2003
# 22      6  25  2003
# 23      6  25  2003
# 24      6  25  2003
# 25      6  25  2003
# 26      6  25  2003
# 27      6  25  2003
# 28      6  25  2003
# 29      6  25  2003
# ...    ..  ..   ...
# 266757  6  25  2004
# 266758  6  25  2004
# 266759  6  25  2004
# 266760  6  25  2004
# 266761  6  25  2004
# 266762  6  25  2004
# 266763  6  25  2004
# 266764  6  25  2004
# 266765  6  25  2004
# 266766  6  25  2004
# 266767  6  25  2004
# ...

# %%
print(dates_mdy.values)
# Out:
# [['6' '25' '2003']
#  ['6' '25' '2003']
#  ['6' '25' '2003']
#  ...,
#  ['6' '25' '2004']
#  ['6' '25' '2004']
#  ['6' '25' '2004']]
